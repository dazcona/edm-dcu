# %% [markdown]
# # EDA
#
# Exploring the dataset!

# %% [markdown]
# Importing libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
font = { 'family': 'DejaVu Sans', 'weight': 'bold', 'size': 22 }
plt.rc('font', **font)

# %%
df = pd.read_csv('../data/data.csv', index_col=0) # user IDIROID as the index

# %%
df.head()
# Out:
#          YEAR  YR_NUM  TOTAL_YEARS EARLY_TRANSFER EARLY_CANX_LEFT  \
# IDIROID
# 239      2014       1            1              N               N
# 243      2014       1            1              N               N
# 926      2014       1            1              N               N
# 932      2016       1            1              N               N
# 946      2014       1            2              N               N
#
#         EARLY_CANX_DEFER FEB_CANX_LEFT FEB_CANX_DEFER  DAYS_TO_FIRST_REG  \
# IDIROID
# 239                    N             N              N                 16
# 243                    N             N              N                 14
# 926                    N             N              N                 22
# 932                    N             N              N                 27
# 946                    N             N              N                 22
#
#           REG_DATE     ...      NUM_MAY_TYPE_A NUM_MAY_TYPE_B NUM_MAY_TYPE_C  \
# IDIROID                ...
# 239      18-SEP-13     ...                 NaN            NaN            NaN
# 243      16-SEP-13     ...                 NaN            NaN            NaN
# 926      24-SEP-13     ...                 NaN            NaN            NaN
# 932      22-SEP-15     ...                 NaN            NaN            NaN
# 946      24-SEP-13     ...                 NaN            NaN            NaN
#
#         NUM_MAY_TYPE_D  NUM_MAY_TYPE_E NUM_MAY_TYPE_X NUM_MAY_TYPE_S  \
# IDIROID
# 239                NaN             NaN            NaN            NaN
# 243                NaN             NaN            NaN            NaN
# 926                NaN             NaN            NaN            NaN
# 932                NaN             NaN            NaN            NaN
# 946                NaN             NaN            NaN            NaN
#
#         EARLIEST_CRM_DATE  DAYS_TO_FIRST_CRM PREV_NUM_CRM
# IDIROID
# 239                   NaN                NaN          NaN
# 243                   NaN                NaN          NaN
# 926                   NaN                NaN          NaN
# 932                   NaN                NaN          NaN
# 946                   NaN                NaN          NaN
#
# [5 rows x 136 columns]

# %%
df.index
# Out:
# Int64Index([   239,    243,    926,    932,    946,    946,   1627,   2283,
#               2285,   2286,
#             ...
#             114725, 114725, 114806, 115123, 115218, 115218, 115437, 115662,
#             115662, 115662],
#            dtype='int64', name='IDIROID', length=16786)

# %%
df.values
# Out:
# array([[2014, 1, 1, ..., nan, nan, nan],
#        [2014, 1, 1, ..., nan, nan, nan],
#        [2014, 1, 1, ..., nan, nan, nan],
#        ...,
#        [2014, 2, 4, ..., nan, nan, nan],
#        [2017, 3, 4, ..., nan, nan, nan],
#        [2018, 4, 4, ..., nan, nan, nan]], dtype=object)

# %%
len(df.columns)
# Out:
# 136

# %%
list(df.columns)
# Out:
# ['YEAR',
#  'YR_NUM',
#  'TOTAL_YEARS',
#  'EARLY_TRANSFER',
#  'EARLY_CANX_LEFT',
#  'EARLY_CANX_DEFER',
#  'FEB_CANX_LEFT',
#  'FEB_CANX_DEFER',
#  'DAYS_TO_FIRST_REG',
#  'REG_DATE',
#  'FACULTY',
#  'DEPT',
#  'CODE',
#  'COURSE',
#  'CANX',
#  'CANX_DATE',
#  'CANX_DESC',
#  'RESULT',
#  'PREV_REG',
#  'PREV_FACULTY',
#  'PREV_DEPT',
#  'PREV_CODE',
#  'PREV_COURSE',
#  'PREV_CANX',
#  'PREV_CANX_DATE',
#  'PREV_CANX_DESC',
#  'PREV_RESULT',
#  'FIRST_REG_DATE',
#  'FIRST_FACULTY',
#  'FIRST_DEPT',
#  'FIRST_CODE',
#  'FIRST_COURSE',
#  'FIRST_CANX',
#  'FIRST_CANX_DATE',
#  'FIRST_CANX_DESC',
#  'FIRST_RESULT',
#  'NEXT_CODE',
#  'NEXT_RESULT',
#  'Y2_RETURN',
#  'NUM_GRANTS',
#  'NUM_SUBJECTS',
#  'PASS_M1',
#  'NUM_M1_SUBJECTS',
#  'NUM_M1_FAILS',
#  'PASS_M5',
#  'NUM_M5_SUBJECTS',
#  'NUM_M5_FAILS',
#  'PASS_M8',
#  'NUM_M8_SUBJECTS',
#  'BIO_SEX',
#  'BIO_BIRTHDATE',
#  'AGE_AT_START',
#  'BIO_ADCITZA',
#  'BIO_ADCNTRYCA',
#  'BIO_ADCNTORIGA',
#  'ORIGIN_CODE',
#  'SCH_EIRCODE',
#  'SCH_ADDR_CODE',
#  'SCH_DEIS',
#  'SCH_FEE_PAYING',
#  'SCH_ENROLMENTS',
#  'STUDENT_TYPE',
#  'YEARS_SINCE_LC',
#  'CAO_POINTS',
#  'LC_MATHS_POINTS',
#  'PERMANENT_ADDR',
#  'PERMANENT_ADDR_CODE',
#  'STUDENT_ADDR',
#  'STUDENT_ADDR_CODE',
#  'ADDRESS',
#  'ADDRESS_CODE',
#  'NUM_MEMBERSHIPS',
#  'NUM_SOCIETIES',
#  'NUM_CLUBS',
#  'ENTERPRISE_ESOC',
#  'ACC_FINANCE',
#  'EARLY_PRINT_SESSIONS',
#  'EARLY_PRINT_PAGES',
#  'DATE_FIRST_LOAN',
#  'NUM_EARLY_LOANS',
#  'DAYS_TO_FIRST_LOAN',
#  'FIRST_LAB_SESSION',
#  'DAYS_TO_FIRST_LAB',
#  'NUM_EARLY_LAB_SESSIONS',
#  'TOTAL_EARLY_LAB_HOURS',
#  'FIRST_ACCESS',
#  'DAYS_TO_FIRST_ACCESS',
#  'NUM_EARLY_ACCESS_DAYS',
#  'NUM_FEB_ACCESS_DAYS',
#  'DAYS_TO_FIRST_DUE_DATE',
#  'FIRST_REL_IND',
#  'DAYS_FIRST_SUBMITTED_EARLY',
#  'FIRST_QUARTILE_RANK',
#  'FIRST_GRADE',
#  'FIRST_ASSIGN_GRADE',
#  'FIRST_GRADE_PC',
#  'DAYS_TO_SECOND_DUE_DATE',
#  'SECOND_REL_IND',
#  'DAYS_SECOND_SUBMITTED_EARLY',
#  'SECOND_QUARTILE_RANK',
#  'SECOND_GRADE',
#  'SECOND_ASSIGN_GRADE',
#  'SECOND_GRADE_PC',
#  'NUM_EARLY_ASSIGNMENTS',
#  'NUM_EARLY_LATES',
#  'EARLY_Q1_SUBS_PC',
#  'EARLY_Q2_SUBS_PC',
#  'EARLY_Q3_SUBS_PC',
#  'EARLY_Q4_SUBS_PC',
#  'NUM_EARLY_CRM',
#  'NUM_EARLY_TYPE_A',
#  'NUM_EARLY_TYPE_B',
#  'NUM_EARLY_TYPE_C',
#  'NUM_EARLY_TYPE_D',
#  'NUM_EARLY_TYPE_E',
#  'NUM_EARLY_TYPE_X',
#  'NUM_EARLY_TYPE_S',
#  'NUM_FEB_CRM',
#  'NUM_FEB_TYPE_A',
#  'NUM_FEB_TYPE_B',
#  'NUM_FEB_TYPE_C',
#  'NUM_FEB_TYPE_D',
#  'NUM_FEB_TYPE_E',
#  'NUM_FEB_TYPE_X',
#  'NUM_FEB_TYPE_S',
#  'NUM_MAY_CRM',
#  'NUM_MAY_TYPE_A',
#  'NUM_MAY_TYPE_B',
#  'NUM_MAY_TYPE_C',
#  'NUM_MAY_TYPE_D',
#  'NUM_MAY_TYPE_E',
#  'NUM_MAY_TYPE_X',
#  'NUM_MAY_TYPE_S',
#  'EARLIEST_CRM_DATE',
#  'DAYS_TO_FIRST_CRM',
#  'PREV_NUM_CRM']

# %%
# Year
df['YEAR'].value_counts()
# Out:
# 2017    3843
# 2016    3663
# 2018    3658
# 2015    2897
# 2014    2725
# Name: YEAR, dtype: int64

# %%
fig = pd.value_counts(df['YEAR'].values, sort=True).plot.barh(figsize=(16, 4))

# %%
fig

# %%
fig.get_figure()

# %%
fig.get_figure().savefig('../figures/exploring_YEAR.png')

# %%
df['YR_NUM'].value_counts()
# Out:
# 1    15395
# 2     1302
# 3       83
# 4        5
# 5        1
# Name: YR_NUM, dtype: int64

# %%
df['TOTAL_YEARS'].value_counts()
# Out:
# 1    14121
# 2     2387
# 3      253
# 4       20
# 5        5
# Name: TOTAL_YEARS, dtype: int64

# %%
df['EARLY_TRANSFER'].value_counts()
# Out:
# N    16380
# Y      406
# Name: EARLY_TRANSFER, dtype: int64

# %%
df['EARLY_CANX_LEFT'].value_counts()
# Out:
# N    16464
# Y      322
# Name: EARLY_CANX_LEFT, dtype: int64

# %%
df['EARLY_CANX_DEFER'].value_counts()
# Out:
# N    16717
# Y       69
# Name: EARLY_CANX_DEFER, dtype: int64

# %%
df['FEB_CANX_LEFT'].value_counts()
# Out:
# N    16259
# Y      527
# Name: FEB_CANX_LEFT, dtype: int64

# %%
df['FEB_CANX_DEFER'].value_counts()
# Out:
# N    16676
# Y      110
# Name: FEB_CANX_DEFER, dtype: int64

# %%
df['DAYS_TO_FIRST_REG'].min(), df['DAYS_TO_FIRST_REG'].max()
# Out:
# (-14, 243)

# %%
fig = pd.cut(df['DAYS_TO_FIRST_REG'], bins=range(-20, 250, 20), include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="b", figsize=(16, 5))

# %%
fig.get_figure().savefig('../figures/exploring_DAYS_TO_FIRST_REG.png', bbox_inches="tight")

# %%
df['REG_DATE'].head(4)
# Out:
# IDIROID
# 239    18-SEP-13
# 243    16-SEP-13
# 926    24-SEP-13
# 932    22-SEP-15
# Name: REG_DATE, dtype: object

# %%
df['REG_DATE'] = pd.to_datetime(df['REG_DATE'])

# %%
import datetime

def get_dates(col, weeks=4):
    base = df[col].min()
    limit = df[col].max()
    dates = []
    x = base.replace(day=1) # first day of the month
    while x < limit:
        dates.append(x)
        x += datetime.timedelta(weeks=weeks)
    return dates

# %%
dates = get_dates('REG_DATE')

# %%
dates[:2]
# Out:
# [Timestamp('2013-08-01 00:00:00'), Timestamp('2013-08-29 00:00:00')]

# %%
fig = pd.cut(df['REG_DATE'], bins=dates, include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="g", figsize=(16, 20))

# %%
fig.get_figure().savefig('../figures/exploring_REG_DATE.png', bbox_inches="tight")

# %%
df['FACULTY'].unique()
# Out:
# array(['HUMANITIES AND SOCIAL SCIENCES', 'ENGINEERING AND COMPUTING',
#        'DCU BUSINESS SCHOOL', 'SCIENCE AND HEALTH', 'DCUBS/HSS',
#        'INSTITUTE OF EDUCATION'], dtype=object)

# %%
df['FACULTY'].value_counts()
# Out:
# HUMANITIES AND SOCIAL SCIENCES    4465
# SCIENCE AND HEALTH                3956
# DCU BUSINESS SCHOOL               3785
# ENGINEERING AND COMPUTING         2082
# INSTITUTE OF EDUCATION            1949
# DCUBS/HSS                          549
# Name: FACULTY, dtype: int64

# %%
fig = pd.value_counts(df['FACULTY'].values, sort=True).plot.barh(figsize=(16, 4))

# %%
fig.get_figure().savefig('../figures/exploring_FACULTY.png', bbox_inches="tight")

# %%
df['DEPT'].unique()
# Out:
# array(['EDUCATION', 'COMPUTING', 'DCU BUSINESS SCHOOL', 'NURSING',
#        'HEALTH AND HUMAN PERFORMANCE', 'PHYSICAL SCIENCES',
#        'BIOTECHNOLOGY', 'MECHANICAL ENGINEERING',
#        'ELECTRONIC ENGINEERING', 'HUMANITIES AND SOCIAL SCIENCES',
#        'SALIS', 'COMMUNICATIONS', 'DCUBS / HSS L&G Programmes',
#        'FIONTAR/COMMUNICATIONS', 'CHEMICAL SCIENCES',
#        'INSTITUTE OF EDUCATION', 'Fiontar agus Scoil na Gaeilge',
#        'LAW AND GOVERNMENT', 'MATHEMATICAL SCIENCES', 'FIONTAR',
#        'Language, Literacy and ECE', 'STEM Ed & Global Studies',
#        'THEOLOGY, PHILOSOPHY AND MUSIC'], dtype=object)

# %%
df['DEPT'].value_counts()
# Out:
# DCU BUSINESS SCHOOL               3785
# INSTITUTE OF EDUCATION            1756
# HUMANITIES AND SOCIAL SCIENCES    1589
# NURSING                           1506
# COMPUTING                         1223
# COMMUNICATIONS                    1168
# LAW AND GOVERNMENT                 750
# HEALTH AND HUMAN PERFORMANCE       633
# SALIS                              571
# DCUBS / HSS L&G Programmes         549
# PHYSICAL SCIENCES                  546
# ELECTRONIC ENGINEERING             513
# BIOTECHNOLOGY                      511
# CHEMICAL SCIENCES                  430
# MECHANICAL ENGINEERING             346
# MATHEMATICAL SCIENCES              330
# EDUCATION                          243
# Language, Literacy and ECE         127
# STEM Ed & Global Studies            66
# FIONTAR                             50
# FIONTAR/COMMUNICATIONS              40
# Fiontar agus Scoil na Gaeilge       36
# THEOLOGY, PHILOSOPHY AND MUSIC      18
# Name: DEPT, dtype: int64

# %%
fig = pd.value_counts(df['DEPT'].values, sort=True).plot.barh(figsize=(16, 10))

# %%
fig.get_figure().savefig('../figures/exploring_DEPT.png', bbox_inches="tight")

# %%
df['CODE'].unique()
# Out:
# array(['ET', 'CA', 'BS', 'INTB', 'BNID', 'PEB', 'SSH', 'CES', 'GCB',
#        'HOR', 'ME', 'EC', 'CE', 'PSSD', 'BAJL', 'ENGLIC', 'CS', 'JHMIL',
#        'EPL', 'EBG', 'MINT', 'EBT', 'AMPS', 'AF', 'ALIS', 'CCS', 'BMED',
#        'EBS', 'JR', 'DME', 'EE', 'ICE', 'ALTS', 'BAJI', 'BAJW', 'GI',
#        'BNGN', 'AC', 'JHPFR', 'AP', 'ATT', 'BAJH', 'BAJP', 'JHPIL',
#        'JHLIL', 'ESH', 'AS', 'SE', 'BT', 'JHPOM', 'JHIIL', 'BSIF', 'GG',
#        'BCL', 'CPSSD', 'PBM', 'CAFM', 'JHIFR', 'BAJM', 'ACM', 'BED',
#        'BNPY', 'JHMFR', 'JHLMS', 'MMA', 'JHLPO', 'EBF', 'MWB', 'CAM',
#        'BHS', 'BNCG', 'JHLIR', 'PHA', 'IR', 'BET', 'PEM', 'BPY', 'BNS',
#        'JHMSI', 'JHLFR', 'MINTD', 'ECE', 'BRH', 'BRM', 'BRE', 'BAJG',
#        'BECE', 'EBC', 'DS', 'EST', 'JZCM'], dtype=object)

# %%
len(df['CODE'].unique())
# Out:
# 91

# %%
fig = pd.value_counts(df['CODE'].values, sort=True).plot.barh(figsize=(16, 20), fontsize=10)

# %%
fig.get_figure().savefig('../figures/exploring_CODE.png', bbox_inches="tight")

# %%
df['COURSE'].unique()
# Out:
# array(['BSc in Education & Training', 'BSc in Computer Applications',
#        'Bachelor of Business Studies',
#        'Bachelor Business Studies International',
#        'BSc in Nursing (Intellectual Disability)',
#        'BSc in Physical Education with Biology',
#        'BSc Sport Science and Health', 'BSc Common Entry into Science',
#        'BSc in Genetics & Cell Biology', 'BSc. in Horticulture',
#        'B.Eng. in Mechatronic Engineering', 'BSc in Enterprise Computing',
#        'B.Eng. in Common Entry into Engineering',
#        'BSc in ComputationalProblem Solv&SW Dev.',
#        'Bachelor of Arts (BAJL)',
#        'BA Languages for Int. Communication(Eng)',
#        'BA in Communication Studies',
#        'Bachelor of Arts J.H.( M.S & Int. Lang)',
#        'BA in Economics, Politics and Law',
#        'BA in Global Business (Germany)',
#        'BSc Marketing, Innovation and Technology',
#        'BA in Global Business (USA)', 'BSc in Aviation Management',
#        'BA in Accounting and Finance',
#        'BA in Applied Language and Intercultural',
#        'BA in Contemporary Culture and Society',
#        'B.Eng. in Biomedical Engineering',
#        'BA in Global Business (Spain)', 'BA in Journalism',
#        'B.Eng. in Digital Media Engineering',
#        'BEng in Electronic Engineering',
#        'BEng Info and Communications Engineering',
#        'BA in Applied Language & Translation Stu',
#        'Bachelor of Arts (BAJI)', 'Bachelor of Arts (BAJW)',
#        'BA Gaeilge agus Iriseoireacht', 'BSc in Nursing (General)',
#        'BSc in Chemical and Pharmaceutical Sc.',
#        'Bachelor of Arts J. H. (Politics&French)',
#        'BSc in Applied Physics', 'BSc Athletic Therapy and Training',
#        'Bachelor of Arts (BAJH)', 'Bachelor of Arts (BAJP)',
#        'Bachelor of Arts J.H. Pol with Int. Lang',
#        'Bachelor of Arts Jnt Hons Law & Int.Lang',
#        'BSc Environmental Science & Health', 'BSc in Analytical Science',
#        'BSc Science Education', 'BSc in Biotechnology',
#        'Bachelor of Arts J.H.(Politics&Med Stu)',
#        'Bachelor of Arts Jnt Hons Irs &Int Lang',
#        'BBS (International Finance)', 'BA Gno agus Gaeilge',
#        'BCL (Law and Society)', 'BSc Physics with Biomedical Sciences',
#        'Common Entry Actuarial and Financial Maths',
#        'Bachelor of Arts Jnt.Hons(Irish&French)',
#        'Bachelor of Arts (BAJM)', 'BSc in Actuarial Mathematics',
#        'Bachelor of Education', 'BSc in Nursing (Mental Health)',
#        'Bachelor of Arts Jnt Hon(MediaStud&Fren)',
#        'Bachelor of Arts Jnt Hons(Law&Media Std)', 'BSc in Multimedia',
#        'Bachelor of Arts Jnt Hons(Law&Politics)',
#        'BA in Global Business (France)',
#        'BSc Manufacturing Eng with Business',
#        'B.Eng. Mechanical & Manufacturing Eng',
#        'Bachelor of Science in Health & Society',
#        "BSc in Children's & General Nursing",
#        'Bachelor of Arts Jnt Hons (Law & Irish)',
#        'BSc in Physics with Astronomy', 'BA in International Relations',
#        'BSc in Physical Education with Maths.',
#        'BSc (Honours) in Psychology',
#        'Bachelor of Nursing Studies (Hons)',
#        'Bachelor of Arts J.H. (MediaStud&Irish)',
#        'Bachelor of Arts Jnt Hons (Law&French)',
#        'BSc Marketing, Innovation & Technology',
#        'BEng Electronic & Computer Engineering',
#        'Bachelor of Religious Education &History',
#        'Bachelor of Religious Education & Music',
#        'Bachelor of Religious Education &English',
#        'Bachelor of Arts (BAJG)', 'Bachelor of Early Childhood Education',
#        'BA in Global Business (Canada)', 'BSc in Data Science',
#        'BSc in Environmental Science & Tech',
#        'BA in Jazz and Contemporary Music Perfor'], dtype=object)

# %%
len(df['COURSE'].unique())
# Out:
# 89

# %%
df['COURSE'].value_counts()
# Out:
# Bachelor of Education                       1331
# Bachelor of Business Studies                1120
# Bachelor of Arts (BAJH)                      879
# BSc in Computer Applications                 741
# BA in Accounting and Finance                 586
# BA in Economics, Politics and Law            549
# BA in Communication Studies                  525
# Bachelor Business Studies International      483
# BCL (Law and Society)                        454
# B.Eng. in Common Entry into Engineering      451
# BSc in Enterprise Computing                  431
# BSc in Nursing (General)                     428
# BSc Common Entry into Science                400
# BSc in Multimedia                            384
# BSc in Education & Training                  369
# BA in Applied Language & Translation Stu     349
# BSc Marketing, Innovation and Technology     334
# BSc in Nursing (Mental Health)               309
# BA in International Relations                296
# BBS (International Finance)                  292
# BSc Marketing, Innovation & Technology       259
# BA in Journalism                             259
# Bachelor of Science in Health & Society      228
# BA in Contemporary Culture and Society       213
# BSc Sport Science and Health                 211
# BSc in Nursing (Intellectual Disability)     205
# BSc in Actuarial Mathematics                 198
# BSc in Physical Education with Biology       197
# BSc in Aviation Management                   193
# BA in Global Business (France)               183
#                                             ...
# BSc Manufacturing Eng with Business           46
# BSc in ComputationalProblem Solv&SW Dev.      41
# BA Gaeilge agus Iriseoireacht                 40
# Bachelor of Arts J.H.( M.S & Int. Lang)       38
# BEng Electronic & Computer Engineering        28
# Bachelor of Arts Jnt Hons Law & Int.Lang      26
# Bachelor of Arts Jnt Hons(Law&Media Std)      25
# BSc in Environmental Science & Tech           24
# Bachelor of Arts Jnt Hons(Law&Politics)       23
# BA in Global Business (Canada)                18
# Bachelor of Arts Jnt Hon(MediaStud&Fren)      18
# BA in Jazz and Contemporary Music Perfor      18
# Bachelor of Arts Jnt Hons (Law&French)        17
# Bachelor of Arts (BAJG)                       15
# Bachelor of Arts J.H.(Politics&Med Stu)       14
# Bachelor of Arts Jnt.Hons(Irish&French)       12
# BEng Info and Communications Engineering      12
# B.Eng. in Digital Media Engineering           12
# Bachelor of Arts J.H. Pol with Int. Lang      11
# Bachelor of Arts Jnt Hons Irs &Int Lang       11
# BSc. in Horticulture                          11
# BEng in Electronic Engineering                10
# Bachelor of Arts J.H. (MediaStud&Irish)       10
# BSc in Data Science                           10
# Bachelor of Arts Jnt Hons (Law & Irish)        9
# Bachelor of Arts (BAJW)                        7
# BA Languages for Int. Communication(Eng)       6
# Bachelor of Nursing Studies (Hons)             5
# Bachelor of Arts J. H. (Politics&French)       4
# BA in Applied Language and Intercultural       3
# Name: COURSE, Length: 89, dtype: int64

# %%
df['CANX'].value_counts(dropna=False)
# Out:
# NaN        15802
#  2018.0      235
#  2017.0      219
#  2016.0      196
#  2015.0      181
#  2014.0      111
#  2019.0       42
# Name: CANX, dtype: int64

# %%
df['CANX_DATE'] = pd.to_datetime(df['CANX_DATE'])

# %%
df['CANX_DATE'].min(), df['CANX_DATE'].max()
# Out:
# (Timestamp('2013-09-23 00:00:00'), Timestamp('2018-09-05 00:00:00'))

# %%
canx_dates = get_dates('CANX_DATE')

# %%
plt.tight_layout()
fig = pd.cut(df['CANX_DATE'], bins=canx_dates, include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="orange", figsize=(16, 20))

# %%
fig.get_figure().savefig('../figures/exploring_CANX_DATE.png', bbox_inches="tight")

# %%
df['CANX_DESC'].value_counts(dropna=False)
# Out:
# NaN                               15802
# COURSE WASNT AS EXPECTED            263
# DISLIKED COURSE                     165
# CHANGE OF MIND                      136
# DEFERRED                            104
# WANT TRANSFER OTHER UNIVERSITY       95
# HEALTH_MEDICAL REASONS               40
# PERSONAL_FAMILY REASONS              34
# FINANCIAL REASONS                    33
# DIDNT FEEL SETTLED IN                24
# FALLING FAR BEHIND IN STUDIES        22
# WITHDRAWN                            15
# DIDNT LIKE DCU                       13
# EMPLOYMENT OPPORTUNITIES             13
# TRAVEL_DISTANCE FROM HOME            11
# STUDENT REGISTRATION ERROR            9
# ACCOMMODATION REASONS                 3
# INTERNAL TRANSFER                     2
# WEB CHANGE OF MIND                    1
# DECEASED                              1
# Name: CANX_DESC, dtype: int64

# %%
df['RESULT'].value_counts(dropna=False)
# Out:
# P     13887
# F      1924
# 0       789
# F0      186
# Name: RESULT, dtype: int64

# %%
list(df['RESULT'].value_counts(dropna=False).keys())
# Out:
# ['P', 'F', '0', 'F0']

# %%
fig = pd.value_counts(df['RESULT'].values).plot.barh(figsize=(16, 4), color="coral")

# %%
fig.get_figure().savefig('../figures/exploring_RESULT.png')

# %%
df['PREV_REG'].value_counts(dropna=False)
# Out:
# NaN        15395
#  2016.0      328
#  2013.0      281
#  2014.0      277
#  2017.0      271
#  2015.0      234
# Name: PREV_REG, dtype: int64

# %%
fig = df['PREV_REG'].value_counts(dropna=True).plot.barh(figsize=(16, 4), color="crimson")
fig.get_figure().savefig('../figures/exploring_PREV_REG.png')

# %%
df['PREV_FACULTY'].value_counts(dropna=False)
# Out:
# NaN                               15395
# SCIENCE AND HEALTH                  392
# ENGINEERING AND COMPUTING           328
# DCU BUSINESS SCHOOL                 293
# HUMANITIES AND SOCIAL SCIENCES      259
# DCUBS/HSS                            81
# INSTITUTE OF EDUCATION               38
# Name: PREV_FACULTY, dtype: int64

# %%
fig = df['PREV_FACULTY'].value_counts(dropna=True).plot.barh(figsize=(16, 4), color="turquoise")
fig.get_figure().savefig('../figures/exploring_PREV_FACULTY.png')

# %%
df['PREV_DEPT'].value_counts(dropna=False)
# Out:
# NaN                               15395
# DCU BUSINESS SCHOOL                 293
# COMPUTING                           173
# PHYSICAL SCIENCES                   115
# HUMANITIES AND SOCIAL SCIENCES      109
# ELECTRONIC ENGINEERING               82
# DCUBS / HSS L&G Programmes           81
# MECHANICAL ENGINEERING               73
# CHEMICAL SCIENCES                    72
# NURSING                              68
# SALIS                                57
# MATHEMATICAL SCIENCES                55
# BIOTECHNOLOGY                        55
# LAW AND GOVERNMENT                   36
# INSTITUTE OF EDUCATION               36
# COMMUNICATIONS                       30
# HEALTH AND HUMAN PERFORMANCE         27
# EDUCATION                            11
# FIONTAR                               9
# FIONTAR/COMMUNICATIONS                5
# Fiontar agus Scoil na Gaeilge         2
# Language, Literacy and ECE            2
# Name: PREV_DEPT, dtype: int64

# %%
df['PREV_CODE'].value_counts(dropna=False).head(10)
# Out:
# NaN     15395
# BS        104
# CA         85
# EC         84
# EPL        81
# CE         73
# INTB       59
# CES        50
# AF         46
# SE         33
# Name: PREV_CODE, dtype: int64

# %%
df['PREV_COURSE'].value_counts(dropna=False).head(10)
# Out:
# NaN                                        15395
# Bachelor of Business Studies                 104
# BSc in Computer Applications                  85
# BSc in Enterprise Computing                   84
# BA in Economics, Politics and Law             81
# B.Eng. in Common Entry into Engineering       73
# Bachelor Business Studies International       59
# BSc Common Entry into Science                 50
# BA in Accounting and Finance                  46
# Bachelor of Arts (BAJH)                       33
# Name: PREV_COURSE, dtype: int64

# %%
df['PREV_CANX'].value_counts(dropna=False)
# Out:
# NaN        16658
#  2016.0       39
#  2017.0       29
#  2014.0       24
#  2015.0       21
#  2018.0        8
#  2013.0        7
# Name: PREV_CANX, dtype: int64

# %%
# df['PREV_CANX_DATE'].value_counts(dropna=False)

# %%
df['PREV_CANX_DESC'].value_counts(dropna=False)
# Out:
# NaN                               16658
# DEFERRED                             41
# COURSE WASNT AS EXPECTED             27
# DISLIKED COURSE                      26
# CHANGE OF MIND                       21
# HEALTH_MEDICAL REASONS                4
# PERSONAL_FAMILY REASONS               3
# FINANCIAL REASONS                     2
# WANT TRANSFER OTHER UNIVERSITY        2
# DIDNT FEEL SETTLED IN                 1
# TRAVEL_DISTANCE FROM HOME             1
# Name: PREV_CANX_DESC, dtype: int64

# %%
fig = df['PREV_CANX_DESC'].value_counts(dropna=True).plot.barh(figsize=(16, 4), color="lavender")
fig.get_figure().savefig('../figures/exploring_PREV_CANX_DESC.png')

# %%
fig = df['PREV_RESULT'].value_counts().plot.barh(figsize=(16, 4), color="grey")

# %%
fig.get_figure().savefig('../figures/exploring_PREV_RESULT.png')

# %%
fig = df['PREV_RESULT'].value_counts(dropna=False).plot.barh(figsize=(16, 4), color="c")

# %%
fig.get_figure().savefig('../figures/exploring_PREV_RESULT_NAN.png')

# %%
# 'FIRST_REG_DATE'
# 'FIRST_FACULTY'
# 'FIRST_DEPT'
# 'FIRST_CODE'
# 'FIRST_COURSE'
# 'FIRST_CANX'
# 'FIRST_CANX_DATE'
# 'FIRST_CANX_DESC'
# 'FIRST_RESULT'

# %%
df['FIRST_REG_DATE'].value_counts(dropna=False).head(4)
# Out:
# 04-SEP-17    1304
# 07-SEP-15    1274
# 05-SEP-16    1233
# 08-SEP-14    1161
# Name: FIRST_REG_DATE, dtype: int64

# %%
df['FIRST_REG_DATE'] = pd.to_datetime(df['FIRST_REG_DATE'])

# %%
canx_dates = get_dates('FIRST_REG_DATE')

# %%
fig = pd.cut(df['FIRST_REG_DATE'], bins=canx_dates, include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="gold", figsize=(16, 20))

# %%
df['NEXT_CODE'].value_counts(dropna=False).head(10)
# Out:
# NaN     15401
# BS        114
# EC         81
# CA         80
# AF         70
# BAJH       67
# CE         57
# EPL        55
# BED        47
# INTB       42
# Name: NEXT_CODE, dtype: int64

# %%
df['NEXT_RESULT'].value_counts(dropna=False)
# Out:
# NaN    15725
# P        766
# F        273
# F0        22
# Name: NEXT_RESULT, dtype: int64

# %%
fig = df['NEXT_RESULT'].value_counts().plot.barh(figsize=(16, 4), color='lightgreen')

# %%
fig.get_figure().savefig('../figures/exploring_NEXT_RESULT.png')

# %%
fig = df['NEXT_RESULT'].value_counts(dropna=False).plot.barh(figsize=(16, 4), color='lightgreen')

# %%
fig.get_figure().savefig('../figures/exploring_NEXT_RESULT_NAN.png')

# %%
df['Y2_RETURN'].value_counts()
# Out:
# Y    14387
# N     2399
# Name: Y2_RETURN, dtype: int64

# %%
df['NUM_GRANTS'].value_counts(dropna=False)
# Out:
# 0    12362
# 1     3746
# 2      638
# 3       40
# Name: NUM_GRANTS, dtype: int64

# %%
df['NUM_SUBJECTS'].value_counts(dropna=False)
# Out:
#  11.0    4635
#  10.0    3294
#  12.0    2507
#  9.0     2170
#  8.0     1286
#  13.0    1039
#  14.0     566
#  1.0      352
#  2.0      259
#  15.0     126
#  3.0      122
#  5.0       92
#  4.0       86
#  7.0       80
#  6.0       57
#  16.0      43
#  17.0      41
#  18.0      18
#  20.0       6
# NaN         3
#  21.0       2
#  23.0       2
# Name: NUM_SUBJECTS, dtype: int64

# %%
fig = df['NUM_SUBJECTS'].value_counts().plot.barh(figsize=(16, 8), color='purple')

# %%
fig.get_figure().savefig('../figures/exploring_NUM_SUBJECTS.png')

# %%
df['PASS_M1'].value_counts()
# Out:
# Y    12781
# N     2873
# 0     1132
# Name: PASS_M1, dtype: int64

# %%
df['PASS_M5'].value_counts()
# Out:
# Y    12038
# N     3821
# 0      927
# Name: PASS_M5, dtype: int64

# %%
df['PASS_M8'].value_counts()
# Out:
# 0    12338
# Y     2461
# N     1987
# Name: PASS_M8, dtype: int64

# %%
df['NUM_M1_SUBJECTS'].value_counts()
# Out:
# 4     5802
# 6     3633
# 3     3177
# 5     2558
# 1      513
# 2      507
# 0      449
# 7       64
# 8       61
# 9       14
# 10       4
# 12       2
# 11       2
# Name: NUM_M1_SUBJECTS, dtype: int64

# %%
df['NUM_M5_SUBJECTS'].value_counts()
# Out:
# 6     6372
# 5     2958
# 7     1877
# 4     1612
# 8     1411
# 9      630
# 10     595
# 1      409
# 11     350
# 2      228
# 3      136
# 0      123
# 12      80
# 13       5
# Name: NUM_M5_SUBJECTS, dtype: int64

# %%
df['NUM_M8_SUBJECTS'].value_counts()
# Out:
# 0.0     12171
# 1.0      1452
# 2.0      1019
# 3.0       712
# 4.0       430
# 5.0       324
# 6.0       229
# 7.0       140
# 8.0       132
# 9.0        79
# 11.0       44
# 10.0       33
# 12.0       18
# Name: NUM_M8_SUBJECTS, dtype: int64

# %%
df['NUM_M1_FAILS'].value_counts()
# Out:
# 0    13913
# 1     1589
# 2      738
# 3      329
# 4      133
# 5       51
# 6       33
# Name: NUM_M1_FAILS, dtype: int64

# %%
df['NUM_M5_FAILS'].value_counts()
# Out:
# 0     12965
# 1      1556
# 2       917
# 3       497
# 4       319
# 5       256
# 6       195
# 7        49
# 8        26
# 9         4
# 10        2
# Name: NUM_M5_FAILS, dtype: int64

# %%
df['BIO_SEX'].value_counts(dropna=False)
# Out:
# F    9211
# M    7575
# Name: BIO_SEX, dtype: int64

# %%
df['BIO_BIRTHDATE'] = pd.to_datetime(df['BIO_BIRTHDATE'])

# %%
bday_dates = get_dates('BIO_BIRTHDATE', weeks=52)

# %%
fig = pd.cut(df['BIO_BIRTHDATE'], bins=bday_dates, include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="darkcyan", figsize=(16, 40))

# %%
fig.get_figure().savefig('../figures/exploring_BIO_BIRTHDATE.png', bbox_inches="tight")

# %%
pd.cut(df['AGE_AT_START'], bins=range(15, 80, 1), include_lowest=True).value_counts(sort=False)
# Out:
# (14.999, 16.0]       0
# (16.0, 17.0]        22
# (17.0, 18.0]      1483
# (18.0, 19.0]      8251
# (19.0, 20.0]      4428
# (20.0, 21.0]      1008
# (21.0, 22.0]       333
# (22.0, 23.0]       151
# (23.0, 24.0]       120
# (24.0, 25.0]       139
# (25.0, 26.0]       104
# (26.0, 27.0]        76
# (27.0, 28.0]        73
# (28.0, 29.0]        44
# (29.0, 30.0]        51
# (30.0, 31.0]        28
# (31.0, 32.0]        22
# (32.0, 33.0]        42
# (33.0, 34.0]        32
# (34.0, 35.0]        28
# (35.0, 36.0]        31
# (36.0, 37.0]        30
# (37.0, 38.0]        28
# (38.0, 39.0]        23
# (39.0, 40.0]        20
# (40.0, 41.0]        19
# (41.0, 42.0]        26
# (42.0, 43.0]        14
# (43.0, 44.0]        14
# (44.0, 45.0]        24
#                   ...
# (49.0, 50.0]         7
# (50.0, 51.0]         8
# (51.0, 52.0]         5
# (52.0, 53.0]         5
# (53.0, 54.0]        10
# (54.0, 55.0]         3
# (55.0, 56.0]         2
# (56.0, 57.0]         6
# (57.0, 58.0]         4
# (58.0, 59.0]         0
# (59.0, 60.0]         3
# (60.0, 61.0]         1
# (61.0, 62.0]         1
# (62.0, 63.0]         2
# (63.0, 64.0]         2
# (64.0, 65.0]         0
# (65.0, 66.0]         1
# (66.0, 67.0]         0
# (67.0, 68.0]         0
# (68.0, 69.0]         0
# (69.0, 70.0]         0
# (70.0, 71.0]         0
# (71.0, 72.0]         0
# (72.0, 73.0]         0
# (73.0, 74.0]         0
# (74.0, 75.0]         0
# (75.0, 76.0]         0
# (76.0, 77.0]         0
# (77.0, 78.0]         0
# (78.0, 79.0]         0
# Name: AGE_AT_START, Length: 64, dtype: int64

# %%
fig = pd.cut(df['AGE_AT_START'], bins=range(15, 70, 1), include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="lightgreen", figsize=(16, 25))

# %%
fig.get_figure().savefig('../figures/exploring_AGE_AT_START.png', bbox_inches="tight")

# %%
# Citizenship
df['BIO_ADCITZA'].value_counts(dropna=False).head(15)
# Out:
# IE    14887
# SA      570
# PL      146
# XB      144
# LT      102
# DE       87
# RO       86
# NG       71
# FR       68
# OM       55
# LV       54
# ES       43
# PH       30
# US       30
# IT       29
# Name: BIO_ADCITZA, dtype: int64

# %%
fig = df['BIO_ADCITZA'].value_counts().plot.barh(figsize=(16, 20), color='olive', fontsize=10)
fig.get_figure().savefig('../figures/exploring_BIO_ADCITZA.png', bbox_inches="tight")

# %%
# Country
df['BIO_ADCNTRYCA'].value_counts(dropna=False).head(15)
# Out:
# IE    13463
# XB      723
# SA      593
# US      215
# NG      196
# PL      144
# DE      111
# PH      103
# LT      101
# RO       93
# FR       88
# LV       59
# OM       57
# ES       42
# CN       42
# Name: BIO_ADCNTRYCA, dtype: int64

# %%
# Country Origin
df['BIO_ADCNTORIGA'].value_counts(dropna=False).head(15)
# Out:
# 1     2057
# 2     1437
# 3      842
# 8      827
# 7      721
# 60     663
# 66     591
# 18     571
# SA     560
# 55     496
# 20     472
# 19     471
# 62     467
# 14     397
# 6      395
# Name: BIO_ADCNTORIGA, dtype: int64

# %%
df['ORIGIN_CODE'].value_counts(dropna=False).head(15)
# Out:
#  4.0     3494
#  5.0     3375
#  2.0     3312
#  6.0     2249
#  7.0     2082
#  3.0     1164
#  0.0      560
#  9.0      221
#  10.0     121
#  11.0     101
#  8.0       55
# NaN        52
# Name: ORIGIN_CODE, dtype: int64

# %%
df['SCH_EIRCODE'].value_counts(dropna=False).head(15)
# Out:
# D      4423
# A      2444
# NaN    2381
# F      1322
# K      1244
# R       979
# Y       817
# H       730
# N       703
# W       693
# C       395
# V       211
# E       162
# X       139
# P       111
# Name: SCH_EIRCODE, dtype: int64

# %%
df['SCH_ADDR_CODE'].value_counts(dropna=False)
# Out:
#  5.0    3247
#  2.0    3047
#  4.0    2770
# NaN     2381
#  6.0    2109
#  7.0    1991
#  3.0    1241
# Name: SCH_ADDR_CODE, dtype: int64

# %%
df['SCH_DEIS'].value_counts(dropna=False)
# Out:
# N      12525
# NaN     2381
# Y       1880
# Name: SCH_DEIS, dtype: int64

# %%
df['SCH_FEE_PAYING'].value_counts(dropna=False)
# Out:
# N      13154
# NaN     2381
# Y       1251
# Name: SCH_FEE_PAYING, dtype: int64

# %%
df['SCH_ENROLMENTS'].value_counts(dropna=False).head(15)
# Out:
# NaN        2381
#  1008.0     269
#  1230.0     211
#  731.0      196
#  706.0      187
#  749.0      183
#  1276.0     183
#  928.0      176
#  783.0      170
#  522.0      164
#  705.0      149
#  1161.0     140
#  1033.0     140
#  625.0      138
#  646.0      137
# Name: SCH_ENROLMENTS, dtype: int64

# %%
df['STUDENT_TYPE'].value_counts(dropna=False).head(15)
# Out:
#  9.0    15074
# NaN      1521
#  7.0       84
#  1.0       48
#  4.0       30
#  5.0       29
# Name: STUDENT_TYPE, dtype: int64

# %%
fig = df['YEARS_SINCE_LC'].value_counts(sort=True).plot.barh(figsize=(16, 12), color='yellow')

# %%
fig.get_figure().savefig('../figures/exploring_YEARS_SINCE_LC.png', bbox_inches="tight")

# %%
fig = pd.cut(df['CAO_POINTS'], bins=range(0, 1000, 50), include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="red", figsize=(16, 8))

# %%
fig.get_figure().savefig('../figures/exploring_CAO_POINTS.png', bbox_inches="tight")

# %%
len(df[df['CAO_POINTS'] == 0])
# Out:
# 192

# %% [markdown]
# There are different codes for CAO_POINTS...

# %%
df['PERMANENT_ADDR'].value_counts(dropna=False)
# Out:
# Co Dublin            1616
# Co Meath             1429
# Co Louth              848
# Co Kildare            817
# Dublin 9              764
# Co Wexford            700
# Dublin 15             607
# Co Donegal            562
# Saudi Arabia          548
# Dublin 11             514
# Dublin 5              501
# Co Monaghan           468
# Co Cavan              465
# Co Wicklow            396
# Co Mayo               386
# Co Westmeath          362
# Dublin 13             360
# Dublin 3              340
# Co Kilkenny           310
# Dublin 7              294
# Co Carlow             255
# Co Roscommon          238
# Co Galway             236
# Co Dublin S           230
# Co Sligo              214
# Dublin 24             189
# Dublin 16             186
# Co Laois              186
# Co Longford           184
# Co Offaly             183
#                      ...
# USA                     8
# DCU                     7
# DCU College Park        6
# Finland                 4
# Malaysia                4
# DCU Shanowen Hall       4
# UAE                     3
# Norway                  3
# Luxembourg              3
# Oman                    3
# Austria                 3
# Belgium                 3
# 0                       2
# Italy                   2
# Sweden                  2
# Unknown                 2
# Lithuania               2
# Bahrain                 1
# Monaco                  1
# Kuwait                  1
# DCU All Hallows         1
# Switzerland             1
# Zimbabwe                1
# Czech Republic          1
# Nigeria                 1
# Poland                  1
# China                   1
# Romania                 1
# Kenya                   1
# NaN                     1
# Name: PERMANENT_ADDR, Length: 93, dtype: int64

# %%
df['STUDENT_ADDR'].value_counts(dropna=False)
# Out:
# 0                      4522
# Dublin 9               1289
# Co Dublin              1124
# Co Meath                939
# DCU Larkfield           677
# Dublin 11               579
# DCU Gateway             573
# Co Louth                479
# Co Kildare              436
# DCU St Patricks         417
# Dublin 15               410
# Dublin 5                384
# DCU                     329
# Dublin 3                290
# Saudi Arabia            276
# Dublin 7                275
# Dublin 13               246
# Dublin                  208
# Co Wicklow              200
# DCU Hazelwood           195
# Co Dublin S             169
# DCU Hampstead           161
# DCU Shanowen Square     157
# Co Monaghan             134
# Co Dublin W             124
# Co Wexford              123
# Dublin 24               123
# Dublin 16               120
# DCU College Park        106
# Co Cavan                101
#                        ...
# DCU All Hallows          14
# Germany                  10
# NI                        9
# Spain                     8
# Co Kerry                  8
# USA                       7
# Co Clare                  7
# Co Limerick               7
# Unknown                   7
# Co Cork                   6
# Dcu                       3
# Malaysia                  2
# Bangladesh                2
# UAE                       2
# China                     2
# Japan                     2
# UK                        2
# Oman                      1
# India                     1
# Kuwait                    1
# Sweden                    1
# Israel                    1
# Nigeria                   1
# Canada                    1
# Kenya                     1
# Poland                    1
# Bahrain                   1
# Zimbabwe                  1
# Switzerland               1
# NaN                       1
# Name: STUDENT_ADDR, Length: 89, dtype: int64

# %%
df['PERMANENT_ADDR'].value_counts(dropna=False)
# Out:
# Co Dublin            1616
# Co Meath             1429
# Co Louth              848
# Co Kildare            817
# Dublin 9              764
# Co Wexford            700
# Dublin 15             607
# Co Donegal            562
# Saudi Arabia          548
# Dublin 11             514
# Dublin 5              501
# Co Monaghan           468
# Co Cavan              465
# Co Wicklow            396
# Co Mayo               386
# Co Westmeath          362
# Dublin 13             360
# Dublin 3              340
# Co Kilkenny           310
# Dublin 7              294
# Co Carlow             255
# Co Roscommon          238
# Co Galway             236
# Co Dublin S           230
# Co Sligo              214
# Dublin 24             189
# Dublin 16             186
# Co Laois              186
# Co Longford           184
# Co Offaly             183
#                      ...
# USA                     8
# DCU                     7
# DCU College Park        6
# Finland                 4
# Malaysia                4
# DCU Shanowen Hall       4
# UAE                     3
# Norway                  3
# Luxembourg              3
# Oman                    3
# Austria                 3
# Belgium                 3
# 0                       2
# Italy                   2
# Sweden                  2
# Unknown                 2
# Lithuania               2
# Bahrain                 1
# Monaco                  1
# Kuwait                  1
# DCU All Hallows         1
# Switzerland             1
# Zimbabwe                1
# Czech Republic          1
# Nigeria                 1
# Poland                  1
# China                   1
# Romania                 1
# Kenya                   1
# NaN                     1
# Name: PERMANENT_ADDR, Length: 93, dtype: int64

# %%
df['STUDENT_ADDR_CODE'].value_counts(dropna=False)
# Out:
#  11.0    4538
#  2.0     3635
#  1.0     2718
#  3.0     2063
#  5.0     1605
#  4.0     1242
#  6.0      391
#  0.0      276
#  7.0      243
#  9.0       43
#  10.0      20
#  8.0       11
# NaN         1
# Name: STUDENT_ADDR_CODE, dtype: int64

# %%
df['ADDRESS'].value_counts(dropna=False)
# Out:
# Co Dublin              1628
# Dublin 9               1515
# Co Meath               1280
# Dublin 11               720
# Co Louth                706
# DCU Larkfield           681
# Co Kildare              677
# Dublin 15               607
# DCU Gateway             574
# Saudi Arabia            548
# Dublin 5                534
# DCU St Patricks         424
# Dublin 3                391
# Dublin 7                368
# Dublin 13               364
# DCU                     329
# Co Wexford              286
# Co Wicklow              279
# Co Dublin S             234
# Co Cavan                217
# Dublin                  215
# Co Monaghan             213
# DCU Hazelwood           195
# Dublin 24               182
# Dublin 16               182
# Co Westmeath            170
# Co Donegal              168
# Co Dublin W             164
# DCU Hampstead           162
# DCU Shanowen Square     157
#                        ...
# Germany                  11
# Spain                     9
# USA                       7
# Unknown                   7
# UK                        5
# Finland                   4
# Dcu                       3
# UAE                       2
# Lithuania                 2
# Japan                     2
# Malaysia                  2
# Belgium                   2
# China                     2
# Bangladesh                2
# Bahrain                   1
# India                     1
# Kuwait                    1
# Oman                      1
# Israel                    1
# Luxembourg                1
# Canada                    1
# Nigeria                   1
# Poland                    1
# Zimbabwe                  1
# Sweden                    1
# Switzerland               1
# Norway                    1
# Kenya                     1
# Romania                   1
# NaN                       1
# Name: ADDRESS, Length: 94, dtype: int64

# %%
df['ADDRESS_CODE'].value_counts(dropna=False)
# Out:
#  2.0     4714
#  3.0     2908
#  1.0     2732
#  5.0     2496
#  4.0     1687
#  6.0      895
#  7.0      678
#  0.0      548
#  9.0       60
#  8.0       31
#  10.0      20
#  11.0      16
# NaN         1
# Name: ADDRESS_CODE, dtype: int64

# %%
df['NUM_MEMBERSHIPS'].value_counts(dropna=False)
# Out:
# 0     3584
# 2     2892
# 3     2746
# 1     2310
# 4     2152
# 5     1411
# 6      792
# 7      420
# 8      238
# 9      107
# 10      69
# 11      30
# 12      15
# 13      10
# 14       5
# 16       3
# 15       2
# Name: NUM_MEMBERSHIPS, dtype: int64

# %%
fig = pd.value_counts(df['NUM_MEMBERSHIPS'].values, sort=True).plot.barh(figsize=(16, 6), color='magenta')

# %%
fig.get_figure().savefig('../figures/exploring_NUM_MEMBERSHIPS.png')

# %%
fig = pd.value_counts(df['NUM_SOCIETIES'].values, sort=True).plot.barh(figsize=(16, 6), color='navy')

# %%
fig.get_figure().savefig('../figures/exploring_NUM_SOCIETIES.png')

# %%
fig = pd.value_counts(df['NUM_CLUBS'].values, sort=True).plot.barh(figsize=(16, 6), color='dodgerblue')

# %%
fig.get_figure().savefig('../figures/exploring_NUM_CLUBS.png')

# %%
df['ENTERPRISE_ESOC'].value_counts()
# Out:
# 0    10757
# 1     6029
# Name: ENTERPRISE_ESOC, dtype: int64

# %%
df['ACC_FINANCE'].value_counts()
# Out:
# 0    12645
# 1     4141
# Name: ACC_FINANCE, dtype: int64

# %%
df['EARLY_PRINT_SESSIONS'].value_counts()
# Out:
# 0    16786
# Name: EARLY_PRINT_SESSIONS, dtype: int64

# %%
df['EARLY_PRINT_PAGES'].value_counts()
# Out:
# 0    16786
# Name: EARLY_PRINT_PAGES, dtype: int64

# %%
df['DATE_FIRST_LOAN'].value_counts().head(5)
# Out:
# 03-OCT-13 12:55:52.000000000    2
# 30-SEP-13 18:12:46.000000000    2
# 21-OCT-13 15:09:52.000000000    2
# 22-SEP-17 13:51:05.000000000    2
# 28-SEP-17 13:34:55.000000000    2
# Name: DATE_FIRST_LOAN, dtype: int64

# %%
df['NUM_EARLY_LOANS'].value_counts().head(4)
# Out:
# 0    7931
# 1    1705
# 2    1223
# 3     941
# Name: NUM_EARLY_LOANS, dtype: int64

# %%
df['DAYS_TO_FIRST_LOAN'].value_counts().head(4)
# Out:
# 14.0    389
# 21.0    353
# 15.0    339
# 16.0    311
# Name: DAYS_TO_FIRST_LOAN, dtype: int64

# %%
df['FIRST_LAB_SESSION'].value_counts().head(4)
# Out:
# 19-SEP-16 15:58:00.000000000    18
# 20-SEP-17 12:04:00.000000000    15
# 18-SEP-17 15:08:00.000000000    14
# 30-SEP-16 13:55:00.000000000    13
# Name: FIRST_LAB_SESSION, dtype: int64

# %%
df['FIRST_LAB_SESSION'] = pd.to_datetime(df['FIRST_LAB_SESSION'])

# %%
lab_dates = get_dates('FIRST_LAB_SESSION')

# %%
fig = pd.cut(df['FIRST_LAB_SESSION'], bins=lab_dates, include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="darkcyan", figsize=(16, 40))

# %%
fig.get_figure().savefig('../figures/exploring_FIRST_LAB_SESSION.png', bbox_inches="tight")

# %%
df['DAYS_TO_FIRST_LAB'].value_counts().head(4)
# Out:
# 14.0    596
# 16.0    522
# 15.0    498
# 22.0    402
# Name: DAYS_TO_FIRST_LAB, dtype: int64

# %%
df['NUM_EARLY_LAB_SESSIONS'].value_counts().head(4)
# Out:
# 0    16786
# Name: NUM_EARLY_LAB_SESSIONS, dtype: int64

# %%
df['TOTAL_EARLY_LAB_HOURS'].value_counts(dropna=False)
# Out:
# 0    16786
# Name: TOTAL_EARLY_LAB_HOURS, dtype: int64

# %%
df['FIRST_ACCESS'].value_counts(dropna=False).head(5)
# Out:
# NaN          1392
# 21-SEP-15     830
# 19-SEP-16     700
# 26-SEP-17     585
# 22-SEP-15     457
# Name: FIRST_ACCESS, dtype: int64

# %%
df['FIRST_ACCESS'] = pd.to_datetime(df['FIRST_ACCESS'])

# %%
access_dates = get_dates('FIRST_ACCESS')

# %%
fig = pd.cut(df['FIRST_ACCESS'], bins=access_dates, include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="darkorange", figsize=(16, 40))

# %%
fig.get_figure().savefig('../figures/exploring_FIRST_ACCESS.png', bbox_inches="tight")

# %% [markdown]
# Difference with the registration...

# %%
df['DAYS_TO_FIRST_ACCESS'].value_counts(dropna=False).head(5)
# Out:
#  1.0    1856
# NaN     1392
#  9.0    1268
#  4.0    1144
#  2.0    1087
# Name: DAYS_TO_FIRST_ACCESS, dtype: int64

# %% [markdown]
# There are negative...

# %%
df['DAYS_TO_FIRST_DUE_DATE'].value_counts(dropna=False)
# Out:
# NaN       4463
#  40.0     1053
#  14.0      773
#  23.0      720
#  39.0      621
#  19.0      613
#  26.0      513
#  68.0      437
#  53.0      430
#  69.0      417
#  51.0      408
#  15.0      327
#  16.0      311
#  30.0      268
#  42.0      257
#  31.0      257
#  45.0      250
#  18.0      249
#  33.0      237
#  29.0      228
#  59.0      211
#  27.0      180
#  66.0      172
#  10.0      168
#  25.0      167
#  7.0       164
#  37.0      157
#  38.0      152
# -3.0       149
#  0.0       117
#           ...
# -12.0       24
#  85.0       20
#  64.0       18
#  48.0       15
#  71.0       15
#  80.0       11
#  57.0       11
#  73.0        9
# -20.0        9
#  74.0        7
#  78.0        6
#  36.0        6
#  90.0        6
#  9.0         5
#  21.0        5
#  60.0        4
#  3.0         3
#  106.0       3
#  70.0        3
#  89.0        3
#  157.0       2
#  79.0        1
#  108.0       1
#  62.0        1
#  44.0        1
#  56.0        1
#  94.0        1
#  84.0        1
#  58.0        1
# -21.0        1
# Name: DAYS_TO_FIRST_DUE_DATE, Length: 89, dtype: int64

# %%
df['FIRST_REL_IND'].value_counts(dropna=False)
# Out:
#  1.0    12206
# NaN      4463
#  0.0      117
# Name: FIRST_REL_IND, dtype: int64

# %%
df['DAYS_FIRST_SUBMITTED_EARLY'].value_counts(dropna=False)
# Out:
# NaN       4463
#  1.0      1958
#  0.0      1892
#  2.0      1234
#  3.0       965
#  4.0       689
#  5.0       494
#  6.0       412
#  7.0       295
#  9.0       274
#  8.0       254
#  16.0      216
#  15.0      207
#  14.0      206
#  17.0      206
#  10.0      197
#  12.0      176
#  13.0      164
#  11.0      149
#  25.0      130
#  24.0      122
#  28.0      108
#  18.0       98
# -1.0        84
#  19.0       84
#  21.0       78
#  43.0       75
#  23.0       73
#  22.0       70
#  20.0       68
#           ...
#  85.0        2
# -39.0        2
#  70.0        2
#  83.0        2
#  81.0        2
# -47.0        2
#  54.0        2
# -43.0        2
#  73.0        2
#  80.0        2
#  78.0        2
#  52.0        2
# -63.0        1
#  55.0        1
#  72.0        1
# -44.0        1
#  92.0        1
# -52.0        1
# -58.0        1
# -22.0        1
#  113.0       1
# -30.0        1
# -62.0        1
#  77.0        1
# -76.0        1
# -57.0        1
# -45.0        1
# -38.0        1
# -35.0        1
#  86.0        1
# Name: DAYS_FIRST_SUBMITTED_EARLY, Length: 132, dtype: int64

# %%
df['FIRST_QUARTILE_RANK'].value_counts(dropna=False)
# Out:
# NaN     4463
#  1.0    3217
#  2.0    3166
#  3.0    3064
#  4.0    2876
# Name: FIRST_QUARTILE_RANK, dtype: int64

# %%
fig = pd.cut(df['FIRST_GRADE'], bins=range(0, 100, 5), include_lowest=True).\
     value_counts(sort=False).plot.barh(rot=0, color="cyan", figsize=(16, 8))

# %%
fig.get_figure().savefig('../figures/exploring_horizontal_FIRST_GRADE.png', bbox_inches="tight")

# %%
df['FIRST_ASSIGN_GRADE'].value_counts(dropna=False)
# Out:
#  1.000000e+02    8852
# NaN              4463
#  1.000000e+01    1598
#  0.000000e+00     561
#  4.000000e+00     433
#  1.500000e+01     293
#  3.000000e+00     223
#  4.294967e+09     117
#  5.000000e+01      58
#  1.000000e+00      56
#  4.294967e+09      47
#  4.294967e+09      37
#  4.000000e+01      33
#  2.000000e+00      10
#  2.500000e+01       4
#  6.000000e+00       1
# Name: FIRST_ASSIGN_GRADE, dtype: int64

# %%
df['FIRST_GRADE_PC'].value_counts(dropna=False)
# Out:
#  0.0      5280
# NaN       5048
# -1.0       994
#  100.0     890
#  50.0      394
#  60.0      306
#  75.0      294
#  70.0      285
#  80.0      273
#  55.0      231
#  90.0      170
#  62.5      151
#  65.0      145
#  66.7      117
#  58.3      112
#  54.2       93
#  95.0       92
#  58.0       89
#  85.0       82
#  40.0       80
#  60.7       64
#  63.0       64
#  45.8       62
#  67.9       58
#  30.0       58
#  64.3       52
#  70.8       48
# -100.0      47
#  45.0       44
#  41.7       44
#           ...
#  89.3        1
#  18.0        1
#  81.5        1
#  12.0        1
#  24.0        1
#  67.3        1
#  74.7        1
#  49.3        1
#  20.8        1
#  41.0        1
#  22.0        1
#  31.0        1
#  13.0        1
#  17.3        1
#  88.8        1
#  84.0        1
#  98.5        1
#  71.3        1
#  92.9        1
#  52.7        1
#  91.7        1
#  95.1        1
#  85.7        1
#  77.5        1
#  41.9        1
#  55.5        1
#  74.0        1
#  70.5        1
#  59.3        1
#  56.5        1
# Name: FIRST_GRADE_PC, Length: 173, dtype: int64

# %% [markdown]
# etc...more features

# %%
df[['CAO_POINTS', 'FIRST_GRADE']].corr()
# Out:
#              CAO_POINTS  FIRST_GRADE
# CAO_POINTS     1.000000    -0.008708
# FIRST_GRADE   -0.008708     1.000000

# %%
fig = df.plot.scatter(x='CAO_POINTS', y='FIRST_GRADE', c='DarkBlue', figsize=(16, 16))

# %%
fig.get_figure().savefig('../figures/exploring_scatter_CAO_POINTS_FIRST_GRADE.png', bbox_inches="tight")

# %%
fig = pd.cut(df['FIRST_GRADE'], bins=range(0, 120, 20), include_lowest=True).\
    value_counts(sort=False).plot.bar(rot=0, color="b", figsize=(16, 4))

# %%
fig.get_figure().savefig('../figures/exploring_FIRST_GRADE.png')

# %%
df['DAYS_TO_SECOND_DUE_DATE'].value_counts(dropna=False)
# Out:
# NaN       7011
#  30.0      785
#  73.0      661
#  14.0      590
#  54.0      486
#  19.0      482
#  82.0      380
#  26.0      370
#  33.0      334
#  23.0      334
#  74.0      297
#  42.0      290
#  64.0      257
#  47.0      250
#  81.0      240
#  45.0      233
#  39.0      216
#  50.0      197
#  21.0      194
#  51.0      190
#  66.0      187
#  52.0      185
#  43.0      174
#  61.0      173
#  0.0       161
#  75.0      155
#  46.0      146
#  25.0      132
#  37.0      118
#  18.0      113
#           ...
#  108.0      11
#  10.0       11
#  3.0        10
# -12.0        9
#  48.0        8
#  59.0        6
#  58.0        6
#  57.0        5
#  72.0        5
#  36.0        4
#  69.0        4
#  27.0        4
#  172.0       3
#  38.0        3
#  65.0        3
#  70.0        3
# -3.0         3
#  90.0        3
#  24.0        3
#  67.0        2
#  115.0       2
#  89.0        2
#  83.0        2
#  8.0         2
#  163.0       1
#  22.0        1
#  56.0        1
#  157.0       1
#  179.0       1
#  7.0         1
# Name: DAYS_TO_SECOND_DUE_DATE, Length: 87, dtype: int64

# %%
df['SECOND_REL_IND'].value_counts(dropna=False)
# Out:
#  1.0    9614
# NaN     7011
#  0.0     161
# Name: SECOND_REL_IND, dtype: int64

# %%
df['DAYS_SECOND_SUBMITTED_EARLY'].value_counts(dropna=False)
# Out:
# NaN       7011
#  0.0      1773
#  1.0      1434
#  2.0       720
#  3.0       538
#  4.0       519
#  5.0       331
#  14.0      231
#  7.0       229
#  11.0      217
#  9.0       213
#  6.0       212
#  10.0      203
#  15.0      200
#  8.0       165
#  17.0      143
#  13.0      127
#  22.0      126
#  16.0      125
#  43.0      120
#  12.0      113
#  18.0      106
#  23.0       87
#  44.0       86
#  28.0       79
#  21.0       72
#  19.0       71
# -1.0        71
#  37.0       61
#  42.0       57
#           ...
#  82.0        3
# -31.0        2
#  85.0        2
# -18.0        2
#  71.0        2
# -19.0        2
#  135.0       1
#  81.0        1
#  68.0        1
#  91.0        1
# -15.0        1
# -41.0        1
# -38.0        1
# -39.0        1
# -22.0        1
#  117.0       1
#  165.0       1
# -17.0        1
#  161.0       1
#  94.0        1
# -20.0        1
#  92.0        1
# -32.0        1
# -58.0        1
#  72.0        1
# -36.0        1
# -24.0        1
#  87.0        1
#  70.0        1
#  172.0       1
# Name: DAYS_SECOND_SUBMITTED_EARLY, Length: 124, dtype: int64

# %%
df['SECOND_QUARTILE_RANK'].value_counts(dropna=False)
# Out:
# NaN     7011
#  1.0    2607
#  2.0    2602
#  3.0    2403
#  4.0    2163
# Name: SECOND_QUARTILE_RANK, dtype: int64

# %%
df['SECOND_GRADE'].value_counts(dropna=False)
# Out:
# NaN           11275
# -1.00000        908
#  100.00000      313
#  3.00000        311
#  4.00000        274
#  60.00000       247
#  70.00000       173
#  10.00000       162
#  9.00000        131
#  7.00000        129
#  58.00000       125
#  6.00000        123
#  8.00000        116
#  50.00000       111
#  2.00000        107
#  65.00000       104
#  63.00000        84
#  80.00000        81
#  68.00000        81
#  55.00000        80
#  0.00000         80
#  5.00000         71
#  62.00000        61
#  75.00000        59
#  8.50000         56
#  90.00000        55
#  64.00000        54
#  9.50000         54
#  7.50000         53
#  67.00000        52
#               ...
#  79.16667         1
#  24.00000         1
#  0.75000          1
#  57.50000         1
#  1.50000          1
#  23.00000         1
#  63.75000         1
#  22.00000         1
#  33.00000         1
#  16.00000         1
#  5.75000          1
#  31.00000         1
#  84.32500         1
#  6.70000          1
#  70.83333         1
#  67.50000         1
#  37.00000         1
#  73.75000         1
#  88.70000         1
#  5.25000          1
#  2.65000          1
#  3.70000          1
#  67.85714         1
#  2.75000          1
#  34.00000         1
#  42.50000         1
#  7.25000          1
#  3.20000          1
#  56.25000         1
#  33.33333         1
# Name: SECOND_GRADE, Length: 167, dtype: int64

# %%
fig = pd.cut(df['SECOND_GRADE'], bins=range(0, 120, 20), include_lowest=True).\
    value_counts(sort=False).plot.bar(rot=0, color="b", figsize=(16, 4))

# %%
fig.get_figure().savefig('../figures/exploring_SECOND_GRADE.png')

# %%
df['SECOND_ASSIGN_GRADE'].value_counts(dropna=False)
# Out:
#  1.000000e+02    7395
# NaN              7011
#  1.000000e+01    1120
#  4.000000e+00     439
#  3.000000e+00     282
#  0.000000e+00     241
#  2.000000e+01      92
#  4.294967e+09      67
#  1.000000e+00      62
#  2.500000e+01      38
#  2.000000e+00      26
#  4.294967e+09       3
#  6.000000e+00       3
#  1.500000e+01       2
#  4.294967e+09       2
#  4.294967e+09       1
#  6.000000e+01       1
#  5.000000e+01       1
# Name: SECOND_ASSIGN_GRADE, dtype: int64

# %%
df['SECOND_GRADE_PC'].value_counts(dropna=False)
# Out:
#  0.0      7376
# NaN       4027
# -1.0       886
#  100.0     883
#  60.0      385
#  70.0      318
#  75.0      251
#  50.0      232
#  80.0      200
#  90.0      188
#  65.0      159
#  58.0      125
#  55.0      119
#  95.0       88
#  63.0       84
#  68.0       82
#  85.0       81
#  40.0       77
#  62.0       61
#  45.0       58
#  64.0       54
#  67.0       53
#  54.0       41
#  72.0       39
#  35.0       39
#  52.0       37
#  84.0       34
#  78.0       33
#  30.0       31
#  93.3       30
#           ...
#  97.5        2
#  49.0        2
#  97.0        2
#  71.4        2
#  18.0        2
#  54.2        2
#  22.0        1
#  5.0         1
#  79.2        1
#  70.8        1
#  24.0        1
#  17.0        1
#  88.3        1
#  91.7        1
#  42.5        1
#  88.7        1
#  0.8         1
#  56.3        1
#  67.9        1
#  72.5        1
#  23.0        1
#  92.5        1
#  37.0        1
#  33.0        1
#  31.0        1
#  34.0        1
#  73.8        1
#  63.8        1
#  84.3        1
#  48.3        1
# Name: SECOND_GRADE_PC, Length: 141, dtype: int64

# %%
df['NUM_EARLY_ASSIGNMENTS'].value_counts(dropna=False)
# Out:
#  0.0     2257
#  1.0     2245
#  2.0     1870
#  3.0     1773
#  4.0     1362
# NaN      1232
#  6.0     1199
#  5.0      816
#  7.0      670
#  9.0      607
#  8.0      532
#  12.0     317
#  10.0     302
#  11.0     257
#  13.0     162
#  15.0     148
#  14.0     143
#  17.0      90
#  16.0      84
#  18.0      83
#  24.0      46
#  25.0      45
#  23.0      44
#  26.0      44
#  21.0      41
#  36.0      38
#  19.0      36
#  27.0      35
#  22.0      35
#  28.0      31
#  35.0      29
#  20.0      28
#  29.0      25
#  34.0      24
#  31.0      20
#  30.0      17
#  33.0      15
#  32.0      13
#  41.0      12
#  37.0      10
#  44.0      10
#  45.0      10
#  42.0      10
#  43.0       7
#  46.0       3
#  40.0       3
#  38.0       2
#  39.0       2
#  47.0       1
#  55.0       1
# Name: NUM_EARLY_ASSIGNMENTS, dtype: int64

# %%
fig = pd.cut(df['NUM_EARLY_ASSIGNMENTS'], bins=range(0, int(df['NUM_EARLY_ASSIGNMENTS'].max()), 10), include_lowest=True).\
    value_counts(sort=False).plot.barh(rot=0, color="b", figsize=(16, 4))

# %%
fig.get_figure().savefig('../figures/exploring_NUM_EARLY_ASSIGNMENTS.png', bbox_inches="tight")

# %%
df['NUM_EARLY_LATES'].value_counts(dropna=False)
# Out:
#  0.0     14100
# NaN       1232
#  1.0      1054
#  2.0       258
#  3.0        58
#  4.0        36
#  5.0        21
#  7.0         8
#  6.0         8
#  8.0         5
#  9.0         2
#  23.0        1
#  11.0        1
#  12.0        1
#  16.0        1
# Name: NUM_EARLY_LATES, dtype: int64

# %%
fig = pd.cut(df['NUM_EARLY_LATES'], bins=range(0, int(df['NUM_EARLY_LATES'].max()), 2), include_lowest=True).\
     value_counts(sort=False).plot.barh(rot=0, color="b", figsize=(16, 4))

# %%
fig.get_figure().savefig('../figures/exploring_NUM_EARLY_LATES.png', bbox_inches="tight")

# %%
df['EARLY_Q1_SUBS_PC'].value_counts(dropna=False)
# Out:
#  0.0      7500
# NaN       1232
#  50.0     1204
#  33.0     1068
#  100.0     952
#  25.0      620
#  67.0      430
#  20.0      379
#  17.0      346
#  40.0      260
#  14.0      186
#  29.0      178
#  11.0      148
#  60.0      145
#  75.0      144
#  22.0      137
#  12.0      120
#  43.0      112
#  44.0       82
#  57.0       76
#  37.0       75
#  56.0       66
#  27.0       64
#  30.0       63
#  10.0       56
#  8.0        56
#  80.0       54
#  71.0       48
#  7.0        47
#  18.0       46
#           ...
#  59.0       11
#  38.0       10
#  52.0       10
#  70.0       10
#  58.0       10
#  26.0        9
#  3.0         8
#  87.0        7
#  91.0        7
#  90.0        6
#  82.0        5
#  77.0        4
#  81.0        4
#  34.0        4
#  61.0        4
#  79.0        4
#  4.0         3
#  69.0        3
#  65.0        3
#  85.0        3
#  93.0        2
#  66.0        2
#  63.0        2
#  74.0        2
#  68.0        2
#  76.0        2
#  72.0        1
#  49.0        1
#  88.0        1
#  51.0        1
# Name: EARLY_Q1_SUBS_PC, Length: 92, dtype: int64

# %%
df['EARLY_Q2_SUBS_PC'].value_counts(dropna=False)
# Out:
#  0.0      7135
#  50.0     1325
#  33.0     1287
# NaN       1232
#  100.0     809
#  25.0      706
#  20.0      433
#  67.0      378
#  17.0      363
#  40.0      319
#  29.0      262
#  14.0      224
#  22.0      166
#  11.0      158
#  43.0      131
#  12.0      128
#  60.0      108
#  44.0      107
#  37.0       98
#  75.0       91
#  36.0       85
#  18.0       80
#  30.0       78
#  57.0       75
#  27.0       74
#  10.0       58
#  9.0        57
#  31.0       54
#  23.0       49
#  56.0       41
#           ...
#  47.0       22
#  55.0       20
#  32.0       19
#  41.0       16
#  71.0       15
#  80.0       15
#  83.0       15
#  6.0        12
#  16.0       12
#  46.0       11
#  70.0       10
#  53.0        6
#  34.0        6
#  58.0        5
#  48.0        5
#  73.0        5
#  64.0        4
#  5.0         4
#  89.0        4
#  86.0        4
#  4.0         3
#  78.0        3
#  54.0        3
#  3.0         2
#  49.0        2
#  87.0        2
#  59.0        1
#  52.0        1
#  51.0        1
#  72.0        1
# Name: EARLY_Q2_SUBS_PC, Length: 75, dtype: int64

# %%
df['EARLY_Q3_SUBS_PC'].value_counts(dropna=False)
# Out:
#  0.0      7556
# NaN       1232
#  50.0     1201
#  33.0     1177
#  100.0     786
#  25.0      669
#  20.0      421
#  17.0      382
#  67.0      353
#  40.0      290
#  14.0      238
#  29.0      227
#  22.0      180
#  11.0      175
#  12.0      134
#  43.0      119
#  37.0       91
#  60.0       87
#  75.0       82
#  30.0       80
#  44.0       77
#  27.0       74
#  10.0       72
#  18.0       66
#  36.0       65
#  8.0        62
#  9.0        61
#  57.0       55
#  21.0       51
#  23.0       45
#           ...
#  39.0       18
#  47.0       16
#  16.0       16
#  41.0       13
#  71.0       13
#  80.0       13
#  55.0       12
#  28.0       12
#  78.0       10
#  46.0       10
#  58.0        8
#  53.0        8
#  4.0         7
#  5.0         7
#  70.0        7
#  48.0        5
#  54.0        5
#  64.0        4
#  86.0        4
#  73.0        3
#  34.0        3
#  89.0        2
#  52.0        2
#  3.0         1
#  61.0        1
#  2.0         1
#  59.0        1
#  76.0        1
#  51.0        1
#  82.0        1
# Name: EARLY_Q3_SUBS_PC, Length: 76, dtype: int64

# %%
df['EARLY_Q4_SUBS_PC'].value_counts(dropna=False)
# Out:
#  0.0      8781
# NaN       1232
#  33.0      922
#  50.0      900
#  100.0     824
#  25.0      532
#  20.0      385
#  17.0      338
#  67.0      303
#  14.0      228
#  11.0      173
#  40.0      154
#  12.0      151
#  29.0      134
#  22.0      124
#  60.0       82
#  10.0       77
#  9.0        76
#  43.0       74
#  75.0       74
#  7.0        62
#  8.0        55
#  44.0       54
#  37.0       54
#  57.0       50
#  18.0       48
#  27.0       43
#  6.0        42
#  30.0       42
#  56.0       39
#           ...
#  38.0       12
#  32.0        9
#  41.0        9
#  89.0        8
#  82.0        8
#  73.0        8
#  54.0        7
#  58.0        7
#  28.0        7
#  70.0        6
#  26.0        5
#  91.0        5
#  2.0         5
#  65.0        4
#  39.0        4
#  34.0        3
#  61.0        3
#  90.0        3
#  69.0        2
#  79.0        2
#  87.0        2
#  81.0        1
#  48.0        1
#  93.0        1
#  49.0        1
#  77.0        1
#  63.0        1
#  94.0        1
#  85.0        1
#  72.0        1
# Name: EARLY_Q4_SUBS_PC, Length: 86, dtype: int64

# %%
df['NUM_EARLY_CRM'].value_counts(dropna=False)
# Out:
# NaN      12967
#  0.0      1855
#  1.0       992
#  2.0       361
#  3.0       235
#  4.0       155
#  5.0        96
#  6.0        33
#  7.0        32
#  8.0        20
#  9.0        12
#  11.0        6
#  10.0        6
#  12.0        4
#  13.0        3
#  15.0        2
#  17.0        1
#  28.0        1
#  25.0        1
#  14.0        1
#  20.0        1
#  21.0        1
#  18.0        1
# Name: NUM_EARLY_CRM, dtype: int64

# %%
indices = ['A', 'B', 'C', 'D', 'E', 'X', 'S']

# %%
df['NUM_FEB_CRM'].value_counts(dropna=False)
# Out:
# NaN      12967
#  0.0      1405
#  1.0      1192
#  2.0       387
#  3.0       267
#  4.0       177
#  5.0       126
#  6.0        90
#  7.0        59
#  8.0        32
#  9.0        24
#  10.0       16
#  11.0        8
#  12.0        8
#  15.0        6
#  14.0        6
#  20.0        3
#  18.0        2
#  17.0        2
#  13.0        2
#  19.0        2
#  29.0        2
#  16.0        1
#  22.0        1
#  21.0        1
# Name: NUM_FEB_CRM, dtype: int64

# %%
pattern = 'NUM_FEB_TYPE_{}'

for i in indices:
    col = pattern.format(i)
    print(col)
    print(df[col].value_counts(dropna=False))
# Out:
# NUM_FEB_TYPE_A
# NaN      12967
#  0.0      2665
#  1.0       722
#  2.0       220
#  3.0       107
#  4.0        36
#  5.0        16
#  6.0        14
#  7.0        11
#  10.0        6
#  9.0         5
#  8.0         3
#  13.0        3
#  11.0        3
#  14.0        2
#  12.0        1
#  15.0        1
#  19.0        1
#  20.0        1
#  21.0        1
#  18.0        1
# Name: NUM_FEB_TYPE_A, dtype: int64
# NUM_FEB_TYPE_B
# NaN     12967
#  0.0     3747
#  1.0       58
#  2.0       11
#  3.0        3
# Name: NUM_FEB_TYPE_B, dtype: int64
# NUM_FEB_TYPE_C
# NaN     12967
#  0.0     3337
#  1.0      380
#  2.0       59
#  4.0       18
#  3.0       17
#  5.0        4
#  6.0        3
#  7.0        1
# Name: NUM_FEB_TYPE_C, dtype: int64
# NUM_FEB_TYPE_D
# NaN     12967
#  0.0     3570
#  1.0      214
#  2.0       31
#  3.0        3
#  4.0        1
# Name: NUM_FEB_TYPE_D, dtype: int64
# NUM_FEB_TYPE_E
# NaN     12967
#  0.0     3719
#  1.0       75
#  2.0       16
#  3.0        5
#  6.0        2
#  7.0        1
#  4.0        1
# Name: NUM_FEB_TYPE_E, dtype: int64
# NUM_FEB_TYPE_X
# NaN      12967
#  0.0      3067
#  3.0       196
#  1.0       179
#  2.0       133
#  4.0        72
#  5.0        59
#  6.0        47
#  7.0        31
#  10.0       11
#  8.0        11
#  9.0         8
#  12.0        2
#  11.0        1
#  20.0        1
#  16.0        1
# Name: NUM_FEB_TYPE_X, dtype: int64
# NUM_FEB_TYPE_S
# NaN     12967
#  0.0     3318
#  1.0      491
#  2.0        9
#  3.0        1
# Name: NUM_FEB_TYPE_S, dtype: int64

# %%
df['NUM_MAY_CRM'].value_counts(dropna=False)
# Out:
# NaN      12967
#  1.0      1330
#  2.0       778
#  3.0       335
#  4.0       227
#  5.0       159
#  0.0       156
#  6.0       119
#  7.0        93
#  8.0        70
#  9.0        67
#  12.0       34
#  10.0       33
#  20.0       30
#  11.0       30
#  22.0       27
#  17.0       20
#  13.0       19
#  14.0       18
#  23.0       17
#  19.0       17
#  30.0       16
#  15.0       15
#  37.0       15
#  28.0       13
#  24.0       13
#  32.0       12
#  25.0       12
#  36.0       11
#  35.0       11
#  27.0       11
#  18.0       10
#  29.0       10
#  33.0       10
#  38.0       10
#  16.0       10
#  26.0        9
#  21.0        8
#  40.0        8
#  34.0        8
#  31.0        7
#  39.0        6
#  41.0        3
#  42.0        2
#  43.0        2
#  48.0        1
#  44.0        1
#  49.0        1
#  72.0        1
#  45.0        1
#  46.0        1
#  47.0        1
#  56.0        1
# Name: NUM_MAY_CRM, dtype: int64

# %%
pattern = 'NUM_MAY_TYPE_{}'

for i in indices:
    col = pattern.format(i)
    print(col)
    print(df[col].value_counts(dropna=False))
# Out:
# NUM_MAY_TYPE_A
# NaN      12967
#  0.0      2245
#  1.0       909
#  2.0       322
#  3.0       155
#  4.0        57
#  5.0        30
#  6.0        25
#  7.0        20
#  8.0        10
#  10.0        9
#  9.0         7
#  11.0        6
#  17.0        4
#  16.0        3
#  13.0        3
#  23.0        3
#  18.0        2
#  14.0        2
#  30.0        1
#  15.0        1
#  12.0        1
#  32.0        1
#  26.0        1
#  27.0        1
#  21.0        1
# Name: NUM_MAY_TYPE_A, dtype: int64
# NUM_MAY_TYPE_B
# NaN     12967
#  0.0     3711
#  1.0       82
#  2.0       22
#  3.0        4
# Name: NUM_MAY_TYPE_B, dtype: int64
# NUM_MAY_TYPE_C
# NaN      12967
#  0.0      3207
#  1.0       459
#  2.0        78
#  3.0        27
#  4.0        22
#  5.0        12
#  7.0         6
#  6.0         5
#  10.0        1
#  9.0         1
#  8.0         1
# Name: NUM_MAY_TYPE_C, dtype: int64
# NUM_MAY_TYPE_D
# NaN      12967
#  0.0      2940
#  1.0       720
#  2.0       103
#  3.0        20
#  4.0        15
#  5.0         8
#  6.0         5
#  10.0        3
#  15.0        1
#  7.0         1
#  14.0        1
#  12.0        1
#  8.0         1
# Name: NUM_MAY_TYPE_D, dtype: int64
# NUM_MAY_TYPE_E
# NaN     12967
#  0.0     3541
#  1.0      229
#  2.0       29
#  3.0       13
#  7.0        3
#  4.0        2
#  6.0        1
#  8.0        1
# Name: NUM_MAY_TYPE_E, dtype: int64
# NUM_MAY_TYPE_X
# NaN      12967
#  0.0      2502
#  1.0       238
#  2.0       195
#  3.0       131
#  5.0       111
#  4.0        92
#  6.0        69
#  20.0       55
#  7.0        42
#  8.0        40
#  9.0        34
#  12.0       28
#  28.0       20
#  36.0       20
#  10.0       18
#  23.0       16
#  30.0       14
#  15.0       13
#  13.0       13
#  17.0       12
#  24.0       12
#  32.0       12
#  29.0       11
#  35.0       11
#  33.0       10
#  18.0        9
#  34.0        9
#  14.0        9
#  27.0        8
#  22.0        8
#  31.0        8
#  19.0        7
#  37.0        6
#  25.0        5
#  26.0        5
#  21.0        5
#  11.0        5
#  38.0        3
#  40.0        3
#  16.0        3
#  39.0        3
#  43.0        1
#  41.0        1
#  44.0        1
#  42.0        1
# Name: NUM_MAY_TYPE_X, dtype: int64
# NUM_MAY_TYPE_S
# NaN     12967
#  0.0     2979
#  1.0      463
#  2.0      371
#  3.0        6
# Name: NUM_MAY_TYPE_S, dtype: int64

# %%
df['EARLIEST_CRM_DATE'].value_counts(dropna=False)
# Out:
# NaN          12967
# 16-NOV-16      118
# 04-NOV-17      107
# 16-FEB-18       90
# 04-SEP-17       75
# 15-FEB-18       72
# 19-FEB-17       71
# 16-DEC-15       66
# 20-APR-18       64
# 08-MAR-17       61
# 28-NOV-14       59
# 05-SEP-17       56
# 14-NOV-17       55
# 24-FEB-17       53
# 09-MAR-17       53
# 15-DEC-15       48
# 07-SEP-17       46
# 18-OCT-17       46
# 02-MAR-17       45
# 06-SEP-17       40
# 19-OCT-17       38
# 09-DEC-13       38
# 03-OCT-17       34
# 23-SEP-17       32
# 03-MAR-17       32
# 03-SEP-17       30
# 28-SEP-17       30
# 24-APR-17       28
# 11-FEB-14       26
# 04-OCT-17       25
#              ...
# 24-JUL-15        1
# 28-JUN-16        1
# 06-MAR-18        1
# 09-OCT-16        1
# 23-MAR-15        1
# 14-AUG-17        1
# 14-OCT-14        1
# 31-MAR-16        1
# 30-MAY-18        1
# 10-DEC-14        1
# 05-JUL-18        1
# 14-SEP-17        1
# 08-FEB-17        1
# 28-JAN-14        1
# 09-NOV-15        1
# 16-FEB-16        1
# 24-MAR-17        1
# 22-JAN-18        1
# 22-JUN-18        1
# 13-APR-17        1
# 26-MAR-18        1
# 23-MAY-18        1
# 20-OCT-16        1
# 30-JAN-14        1
# 14-JUN-18        1
# 26-FEB-16        1
# 04-SEP-14        1
# 10-AUG-16        1
# 11-JUN-15        1
# 23-FEB-15        1
# Name: EARLIEST_CRM_DATE, Length: 658, dtype: int64

# %%
df['DAYS_TO_FIRST_CRM'].value_counts(dropna=False)
# Out:
# NaN       12967
#  72.0        65
#  61.0        52
#  167.0       50
#  0.0         49
#  71.0        47
#  1.0         47
#  100.0       43
#  162.0       43
#  23.0        42
# -1.0         41
#  165.0       39
#  70.0        38
#  164.0       38
#  29.0        38
#  21.0        37
#  81.0        37
#  22.0        37
#  28.0        36
#  44.0        35
#  24.0        34
#  19.0        33
#  15.0        33
#  163.0       32
#  178.0       31
#  228.0       31
#  3.0         29
#  37.0        29
#  30.0        29
#  2.0         29
#           ...
# -58.0         1
# -148.0        1
# -38.0         1
# -37.0         1
#  237.0        1
#  273.0        1
#  259.0        1
#  327.0        1
#  317.0        1
#  344.0        1
#  234.0        1
#  307.0        1
#  312.0        1
#  251.0        1
#  258.0        1
#  107.0        1
#  236.0        1
#  340.0        1
#  310.0        1
# -47.0         1
#  194.0        1
#  245.0        1
#  270.0        1
# -39.0         1
#  278.0        1
# -29.0         1
#  342.0        1
#  283.0        1
#  346.0        1
#  263.0        1
# Name: DAYS_TO_FIRST_CRM, Length: 365, dtype: int64

# %%
df['PREV_NUM_CRM'].value_counts(dropna=False)
# Out:
# NaN      16614
#  0.0       100
#  1.0        29
#  3.0        13
#  2.0        12
#  4.0         9
#  5.0         4
#  7.0         1
#  14.0        1
#  9.0         1
#  17.0        1
#  8.0         1
# Name: PREV_NUM_CRM, dtype: int64

# %% [markdown]
# ## Utils

# %%
df["FIRST_LAB_SESSION"].head(5)
# Out:
# IDIROID
# 239                   NaT
# 243                   NaT
# 926                   NaT
# 932   2015-11-18 12:46:00
# 946                   NaT
# Name: FIRST_LAB_SESSION, dtype: datetime64[ns]

# %%
import datetime

# %%
_str = '23-SEP-14 13:59:00.000000000'

# %%
datetime.datetime.strptime(_str, '%d-%b-%y %H:%M:%S.000000000')
# Out:
# datetime.datetime(2014, 9, 23, 13, 59)

# %%
pd.to_datetime(df.head(5)['FIRST_LAB_SESSION'])
# Out:
# IDIROID
# 239                   NaT
# 243                   NaT
# 926                   NaT
# 932   2015-11-18 12:46:00
# 946                   NaT
# Name: FIRST_LAB_SESSION, dtype: datetime64[ns]
